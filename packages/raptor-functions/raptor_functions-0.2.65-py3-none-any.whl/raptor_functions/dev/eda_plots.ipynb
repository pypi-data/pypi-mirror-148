# %%
from raptor_functions.supervised.datasets import get_data

# %%
df = get_data('handheld_data')
df
# Out:
#      exp_unique_id  exp_name  timesteps  sensor_1  sensor_2  sensor_3  \
# 0                0  Test 24           1   131.938   132.443   177.444
# 1                0  Test 24           2   133.078   133.972   177.444
# 2                0  Test 24           3   131.812   132.064   177.622
# 3                0  Test 24           4   131.059   132.064   177.444
# 4                0  Test 24           5   131.435   131.938   177.622
# ..             ...       ...        ...       ...       ...       ...
# 123             29  Test 24         124   131.812   132.317   176.558
# 124             29  Test 24         125   131.560   132.190   176.558
# 125             29  Test 24         126   130.933   131.938   176.735
# 126             29  Test 24         127   131.435   132.317   176.735
# 127             29  Test 24         128   130.684   131.686   176.735
#
#      sensor_4  sensor_5  sensor_6  sensor_7  sensor_8  sensor_9  sensor_10  \
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import random
# Select one random experiment
i =

# %%
import matplotlib.pyplot as plt
matplotlib.use("pgf")
matplotlib.rcParams.update({
    "pgf.texsystem": "pdflatex",
    'font.family': 'serif',
    'text.usetex': True,
    'pgf.rcfonts': False,
})

# %%
# input
exp_number = random.randint(0, df['exp_unique_id'].nunique())
sensor_number = random.randint(1,12)
# ---------------------------------
# Pre-processing
df_exp = df.loc[df['exp_unique_id'] == exp_number]
sensor = 'sensor_' + str(sensor_number)
# 
fig, ax = plt.subplots(figsize=(6, 4), tight_layout=True)
ax.plot(df_exp['time_elapsed'], df_exp[sensor])
ax.set_xlabel(r'{Time [s]}')
ax.set_ylabel(r'{Response [mV]}')
ax.set_title('Experiment ' + str(exp_number) + ': ' + sensor)
plt.savefig('histogram.pgf')
plt.savefig('histogram.pdf')
